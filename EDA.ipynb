# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('../Datasets/Analytics Vidya/train_PDjVQMB.csv')

# %%
test = pd.read_csv('../Datasets/Analytics Vidya/test_lTY72QC.csv')

# %%
data
# Out:
#             ID  Age  Gender         Income     Balance  Vintage  \
# 0     84e2fcc9   36  Female       5L - 10L   563266.44        4
# 1     57fea15e   53  Female   Less than 5L   875572.11        2
# 2     8df34ef3   35  Female  More than 15L   701607.06        2
# 3     c5c0788b   43  Female  More than 15L  1393922.16        0
# 4     951d69c4   39  Female  More than 15L   893146.23        1
# ...        ...  ...     ...            ...         ...      ...
# 6645  a8216afd   61    Male       5L - 10L  1354526.19        4
# 6646  153a306b   42  Female       5L - 10L   596286.54        3
# 6647  d4075a95   29    Male   Less than 5L   979298.19        2
# 6648  5855b142   66  Female      10L - 15L   395233.65        3
# 6649  57b39511   37    Male  More than 15L   826947.27        1
#
#       Transaction_Status Product_Holdings  Credit_Card Credit_Category  \
# 0                      0                1            0         Average
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6650 entries, 0 to 6649
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  6650 non-null   object
#  1   Age                 6650 non-null   int64
#  2   Gender              6650 non-null   object
#  3   Income              6650 non-null   object
#  4   Balance             6650 non-null   float64
#  5   Vintage             6650 non-null   int64
#  6   Transaction_Status  6650 non-null   int64
#  7   Product_Holdings    6650 non-null   object
#  8   Credit_Card         6650 non-null   int64
#  9   Credit_Category     6650 non-null   object
#  10  Is_Churn            6650 non-null   int64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 571.6+ KB

# %%
data.corr()
# Out:
#                          Age   Balance   Vintage  Transaction_Status  \
# Age                 1.000000  0.002154  0.017353            0.032166
# Balance             0.002154  1.000000 -0.019385           -0.005088
# Vintage             0.017353 -0.019385  1.000000           -0.027286
# Transaction_Status  0.032166 -0.005088 -0.027286            1.000000
# Credit_Card         0.012089 -0.025259  0.001856            0.006526
# Is_Churn            0.204301  0.056380  0.020152           -0.086917
#
#                     Credit_Card  Is_Churn
# Age                    0.012089  0.204301
# Balance               -0.025259  0.056380
# Vintage                0.001856  0.020152
# Transaction_Status     0.006526 -0.086917
# Credit_Card            1.000000 -0.000848
# Is_Churn              -0.000848  1.000000

# %%
id_col = data.pop('ID')
id_colt = test.pop('ID')

# %%
vgrp = data.groupby(by= 'Vintage' )
tvgrp = test.groupby(by= 'Vintage' )

# %%
vgrp.get_group(0)
# Out:
#       Age  Gender         Income     Balance  Vintage  Transaction_Status  \
# 3      43  Female  More than 15L  1393922.16        0                   1
# 8      60  Female      10L - 15L  1465812.54        0                   0
# 24     40    Male   Less than 5L   628551.00        0                   1
# 34     54  Female   Less than 5L   903320.55        0                   0
# 38     41  Female   Less than 5L    17028.00        0                   1
# ...   ...     ...            ...         ...      ...                 ...
# 6589   28    Male  More than 15L   347921.46        0                   0
# 6594   53  Female   Less than 5L  1566675.72        0                   0
# 6603   44    Male       5L - 10L   186957.90        0                   0
# 6621   31    Male   Less than 5L   747055.26        0                   0
# 6629   29    Male       5L - 10L  1089048.24        0                   1
#
#      Product_Holdings  Credit_Card Credit_Category  Is_Churn
# ...

# %%
sns.countplot(x="Vintage",hue="Is_Churn",data=data)
# Out:
# <AxesSubplot:xlabel='Vintage', ylabel='count'>

# %%
sns.countplot(x="Gender",hue="Is_Churn",data=data)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="Income",hue="Is_Churn",data=data)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
sns.countplot(x="Product_Holdings",hue="Is_Churn",data=data)
# Out:
# <AxesSubplot:xlabel='Product_Holdings', ylabel='count'>

# %%
sns.countplot(x="Credit_Category",hue="Is_Churn",data=data)
# Out:
# <AxesSubplot:xlabel='Credit_Category', ylabel='count'>

# %%
sns.countplot(x="Credit_Card",hue="Is_Churn",data=data)
# Out:
# <AxesSubplot:xlabel='Credit_Card', ylabel='count'>

# %%
sns.countplot(x="Transaction_Status",hue="Is_Churn",data=data)
# Out:
# <AxesSubplot:xlabel='Transaction_Status', ylabel='count'>

# %%
sns.boxenplot(y='Age',x='Vintage',data=data)
# Out:
# <AxesSubplot:xlabel='Vintage', ylabel='Age'>

# %%
sns.boxenplot(y='Age',x='Vintage',data=test)
# Out:
# <AxesSubplot:xlabel='Vintage', ylabel='Age'>

# %%
sns.relplot(
    data=data,
    x="Age", y="Balance", col="Product_Holdings",
    hue="Is_Churn", style="Is_Churn",size = 'Vintage')

# %%
sns.relplot(
    data=test,
    x="Age", y="Balance", col="Product_Holdings",
    size = 'Vintage')

# %%
sns.relplot(
    data=vgrp.get_group(0),
    x="Age", y="Balance", col="Product_Holdings",
    hue="Is_Churn", style="Is_Churn",size='Credit_Category')

# %%
sns.relplot(
    data=vgrp.get_group(0),
    x="Age", y="Product_Holdings", col="Credit_Card",
    hue="Is_Churn", style="Is_Churn",size='Transaction_Status')

# %%
sns.relplot(
    data=vgrp.get_group(0),
    x="Age", y="Product_Holdings", col="Credit_Card",
   size='Transaction_Status')

# %%
sns.relplot(
    data=data,
    x="Age", y="Balance", col="Product_Holdings",
    hue="Is_Churn", style="Is_Churn",size = 'Vintage')

# %%
sns.relplot(
    data=data, kind="line",
    x="Age", y="Balance", col="Transaction_Status",
    hue="Is_Churn", size="Vintage", style="Is_Churn",
    facet_kws=dict(sharex=False),
)

# %%
sns.relplot(
    data=data, kind="line",
    x="Age", y="Credit_Category", col="Transaction_Status",
    hue="Is_Churn", size="Vintage", style="Is_Churn",
    facet_kws=dict(sharex=False),
)

# %%
sns.relplot(
    data=data, kind="line",
    y="Age", x="Vintage", col="Transaction_Status",
    hue="Is_Churn", size="Product_Holdings", style="Is_Churn",
    facet_kws=dict(sharex=False),
)

# %%
sns.relplot(
    data=data, kind="line",
    y="Age", x="Vintage", col="Product_Holdings",
    hue="Is_Churn", size="Transaction_Status", style="Is_Churn",
    facet_kws=dict(sharex=False),
)

# %%
sns.relplot(
    data=test, kind="line",
    y="Age", x="Vintage", col="Product_Holdings",
     size="Transaction_Status",
    facet_kws=dict(sharex=False),
)

# %%
sns.relplot(
    data=data, kind="line",
    y="Balance", x="Vintage", col="Product_Holdings",
    hue="Is_Churn", size="Transaction_Status", style="Is_Churn",
    facet_kws=dict(sharex=False),
)

# %%
sns.relplot(
    data=data, kind="line",
    x="Age", y="Balance", col="Product_Holdings",
    hue="Is_Churn", style="Is_Churn",
)

# %%
sns.relplot(
    data=data, kind="line",
    x="Age", y="Credit_Category", col="Product_Holdings",
    hue="Is_Churn", style="Is_Churn",
)

# %%
#sns.displot(data=data, x="Age", col="Product_Holdings", kde=True)

# %%
sns.relplot(
    data=data, kind="line",
    x="Income", y="Balance", col="Product_Holdings",
    hue="Is_Churn", style="Is_Churn",
)

# %%
sns.catplot(data=data, kind="swarm", x="Product_Holdings", y="Vintage", hue="Is_Churn")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-5d73c6a663de> in <module>
# ----> 1 sns.catplot(data=data, kind="swarm", x="Product_Holdings", y="Vintage", hue="Is_Churn")
#
# ~\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3832
#    3833     # Draw the plot onto the facets
# -> 3834     g.map_dataframe(plot_func, x=x, y=y, hue=hue, **plot_kws)
# ...

# %%
data.Income.unique()
# Out:
# array(['5L - 10L', 'Less than 5L', 'More than 15L', '10L - 15L'],
#       dtype=object)

# %%
sns.relplot(
    data=data, kind="line",
    y="Balance", x='Age',
    hue="Is_Churn", style="Is_Churn",
)

# %%
sns.catplot(data=data, kind="violin", x="Product_Holdings", y="Age", hue="Is_Churn", split=True)

# %%
sns.catplot(data=data, kind="violin", x="Income", y="Balance", hue="Is_Churn", split=True)

# %%
sns.catplot(data=data, kind="violin", x="Product_Holdings", y="Balance", hue="Is_Churn", split=True)
